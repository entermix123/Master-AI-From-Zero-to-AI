# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset (tab-separated file)
data = pd.read_csv('data.csv', sep=';')

# Display first rows
print("First 5 rows:")
print(data.head())

# Calculate median income
median_income = data['Income'].median()
print("\nMedian Income:", median_income)

# Create histogram
plt.figure()
plt.hist(data['Income'], bins=5)
plt.title('Income Distribution')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()
# Out:
# First 5 rows:
#       Name  Age         City  Income Gender
# 0    Alice   18     New York   15000      F
# 1      Bob   25  Los Angeles   30000      M
# 2  Charlie   19      Chicago   18000      F
# 3    David   16      Houston    8000      M
# 4      Eve   22      Phoenix    8000      F
#
# Median Income: 15000.0
