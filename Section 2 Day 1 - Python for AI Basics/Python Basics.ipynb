# %% [markdown]
# # Python Basics

# %%
# Variables Types

x = 5 
y = 2.5
name = "Vivian"
is_student = True

# Operators +, -, *, /, **, % 
sum = x * y
product = x + y
power = x ** 2

print(power)
# Out:
# 25

# %%
# Control Flow

if x > y:
    print (f"{x} is greater than {y}")
else:
    print((f"{y} is greater than {x}"))
# Out:
# 5 is greater than 2.5

# %%
# Loops
for i in range(5):
    print(f"i = {i}")
j = 1
while j < 8:
    print(f"j = {j}")
    j += 1
    
print("I am out")
# Out:
# i = 0
# i = 1
# i = 2
# i = 3
# i = 4
# j = 1
# j = 2
# j = 3
# j = 4
# j = 5
# j = 6
# j = 7
# I am out

# %%
# functions

def greet(name):
    return f"Hello, {name}"

print(greet("Scott"))
# Out:
# Hello, Scott
